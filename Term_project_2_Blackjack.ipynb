# %% [markdown]
# <a href="https://colab.research.google.com/github/Mathieu-Allaire/BlackJack-Game-Simulation/blob/main/Term_project_2_Blackjack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Probabilities of Winning a Blackjack Game Based on Strategy
#
# 360-420-DW
#
# Winter 2022
#
# Term Project 2
#
# Mathieu Allaire (Section 03) and Krasimir Kirov (Section 03)
#
# May 18th, 2022

# %% [markdown]
# ##Introduction
#
# For our project, we wanted to see how the strategy of the player affects their probability of winning a game of Blackjack. Specifically,  we wanted to analyze how the point total until which the player decides to hit affects the number of Blackjack games he wins. We decided to analyze this problem since many Blackjack players use some determined strategies charts while playing to help them find the best way to play their hand. Therefore, by exploring this problem, we will determine which strategy gives the player the biggest probability of winning against the dealer, which will help the Blackjack players in their decision making. This will be useful for any person wanting to play Blackjack at the casino.
# ##
# To verify how the hand at which the player decides to hit up to affects their probability of winning, we chose to simulate a Blackjack game that follows the official rules. For Blackjack hands having a total amount of points between 9 and 19 and at which the player decides to hit up to, we compared the games they won from a total of 1000 games played. We then replayed these 1000 games 100 times for each of these hands in order to get a precise and accurate average of the number of games out of 1000 the player won. Next, we compared these data to actual observed probabilities. Our hypothesis was that a Blackjack player who decides to hit up to a larger hand will win more games out of a 1000. The reasoning behind it is that in Blackjack, the higher hand between the dealer and the player wins. Hence, we think that the hand at which the player has the most probability of winning when standing is 19.

# %% [markdown]
# ##Theory of model
#
# In order to achieve our intended objective, we need a model that can simulate a Blackjack game and record if the player won or lost the game. Our model will do that for each player hand between 9 and 19 by simulating 1000 games. To be able to do that, our model should be designed to follow the official Blackjack rules.
# ##
# Blackjack is a gambling game where players compete against the dealer. In our model, it will be assumed that only one player plays against the dealer. This assumption does not impact our accuracy of probabilities, because in Blackjack, the players only play against the dealer and not against themselves. To win a Blackjack game, there are two possibilities. The first possibility is that the hand of the player is greater than that of the dealer. The second possibility is that the dealer busts, meaning his hand total goes beyond 21. In our model, both these possibilities will be taken into account.
# ##
# Then, our model will be built to respect the chain of events in an official Blackjack game (Pokerstars Casino). First of all, our model will have six classical decks of cards. Each card will be worth its number, with face cards being worth 10. This is shown in figure 1.1. It is important to note that the Ace cards are worth either 1 or 11, depending on the context and on the player’s decision. Next, the model will randomly give two cards to the player and two cards to the dealer. However, the second card of the dealer will be faced down so that the player cannot base his decision on it. To illustrate, an example of this setup is provided in Figure 1.2.
# ##
# At this point of the game, the player has several choices. He can hit, which means that he requests another card. He can stand, which means he stops requesting cards. Additionally, the player can choose to double down, which means he hits one last time by doubling his initial bet. Finally, if the two initial cards of the player have the same value, he can choose to split, which means that he separates the two cards and starts to play two games in one. For the purposes of our model, it will be assumed that the player only has the option to hit or stand. This is for the reason that the double strategy is related to betting, which is not related to our problem. Also, we assume the player does not use the split strategy, so that we can focus our model on the differences between hitting and standing. As our model computes the probabilities of winning a hand that is at least totalling 9, the splitting method will not be useful and thus will not skew the probabilities significantly.
# ##
# Another important information is that our model will consider the event of a tie between the dealer and the player as a loss ( so that the probability of winning is not skewed).On top of that, in our model, the dealer is forced to hit until he reaches the value of 17, as it is in the large majority of official casinos (Pokerstars Casino).Finally, our model will be designed so that the player hits until he reaches a certain hand value. In fact, our model will compute the probabilities of winning a certain hand until which the player decided to hit. For instance, it will calculate the number of games won when the player decides to hit until he reaches a hand of 9, then a hand of 10 and, then 11,and so on , until it reaches 19. This therefore implies that our model will force the player to hit until he reaches at least a hand with total value 9, where he will stand.
# ##
# The model will simulate all the 1000 games for each hand and record how many of them the player won. During the 1000  games, if the deck empties itself, it will be reshuffled and ready to play again. This is how the game is played in casinos,wherein the dealer separates the already played cards from the deck and only reshuflles it once it is empty (PokerStar Casino). We will do the same in our model. Then, our model will play these 1000 games 100 times for each strategy (the strategy being the hand the player decides to hit up to). This will allow the model to find the average number of games won out of a 1000. This will provide the necessary data in order for us to create a graph that shows the probabilities of winning the hand. Namely, the X-axis will be the hand's total value for which the player hit up to and the Y-Axis will be the number of games won out of a 1000.

# %% [markdown]
# #Figure 1.1
#  Value of each card in Blackjack
#
# (from: “Play Online Blackjack.” *PokerStars Casino*. 2022. https://cad.pokerstarscasino.com/games/blackjack/. Accessed 14 May 2022.)
#
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Figure 1.2
#
# Setup of a classic Blackjack Game
#
# (from a Screenshot of the *Blackjack* application of the *Google Play* store)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Numerical method
#   The blackjack game was simulated using functions and algorithms. All
#   constants used in the simulation, including the values of the cards and the number of points, have discrete and exact values, which means there were no approximations made during the computations of the results of each blackjack game. Once the strategies and the rules had been determined for our specific blackjack (as explained in the theory of model), we separated the code into 3 separate phases: The creation of the game, the simulation of the game, and the illustration of the results of the simulation of the game.

# %% [markdown]
# ##Numerical method
#   The blackjack game was simulated using functions and algorithms. All constants used in the simulation, including the values of the cards and the number of points, have discrete and exact values, which means there were no approximations made during the computations of the results of each blackjack game. Once the strategies and the rules had been determined for our specific blackjack (as explained in the theory of model), we separated the code into 3 separate phases: The creation of the game, the simulation of the game, and the illustration of the results of the simulation of the game.
# ## First phase
#   In the first phase, the game was created using functions and algorithms to set conditions for how the player and the dealer should play each game out depending on the cards they receive and their current points. The deck used for each game was a combination of 6 shuffled decks comprising 52 cards each in which the aces counted for 1 point or 11 points depending on the situation, the jacks, queens and kings counted for 10 points, and all the other cards counted for their respective number of points. Each card was created 4 times per deck for each sort of suit (diamonds, spades, hearts, clubs). Then, the player, followed by the dealer, would pick cards out of this big, shuffled deck. While the initial probability of picking each card was initially 1/312, the probability of picking any next card would lower to 1/311, then 1/310, etc. This is because in our model we keep the cards out of play once they are picked by the dealer or the player, which means the probability of picking a card that has not been picked yet will keep on increasing until it is picked or it is the last card left, at which point we call the shuffle_deck function again to reshuffle another 6 decks and continue where the function left off.
# ##
# The player and the dealer would then play the game until either their total amount of points went above 21, at which point they would lose, or they would go above their specific strategy. In the case of the player, this strategy changed depending on the input and was represented by a number from 9 to 20 that changed every 1000 games in the simulation. In the dealer’s case, the strategy did not change, as the dealer was obligated to stop picking cards if he reached a number of points greater than or equal to 17.
# ## Second phase
#   In the second phase, the game was simulated 1000 times per strategy used by the player, and the number of wins for each strategy was recorded in the list_of_results, while the number of games were recorded in the list_of_games. Then, this whole experiment was repeated 99 other times for a total of 100 experiments involving each strategy being used in a game of blackjack 1000 times. Once the results had been compiled, the total amount of wins per experiment and per strategy used were recorded in the pandas_list.
# ## Third phase
#   In the third phase, the data that represented the average amount of wins per 1000 games for each strategy used by the player was stored in a data frame and illustrated on a graph using seaborn, which showed how the strategies affected the probabilities of winning for the player. We were then able to show which strategy was the most effective for the player on average. This data could then be used to calculate an approximate probability of winning for each strategy described in the simulation.

# %% [markdown]
# ## CODE OF OUR MODEL:

# %% [markdown]
# ## PHASE 1

# %%
import random
def shuffle_decks():
#The shuffle_decks function creates cards with different values for each sort
#and for each of the 6 decks we use. It then creates a deck by randomly assigning them an index.
  decks=[]
  for i in range (0,6):
    for j in range(0,4):
      decks.append('Ace') #The ace's value changes depending on the situation
      decks.append(2)
      decks.append(3)
      decks.append(4)
      decks.append(5)
      decks.append(6)
      decks.append(7)
      decks.append(8)
      decks.append(9)
      decks.append(10)
      decks.append(10) #The jacks,queens and kings also have values of 10 in the game of Blackjack
      decks.append(10)
      decks.append(10)
  random.shuffle(decks) #This will create the element of randomness to the card picked.
  return decks

def receive_card(decks):
#The receive_card function picks the first card from the shuffled deck and removes it from the deck.
  received_card=decks[0]
  decks.remove(received_card)
  return received_card

def assign_initial_points(received_cards_list,points):
#The assign_initial_points function gives an initial amount of points to the player
#after he receives his two initial cards
  for i in range(0,len(received_cards_list)):
    if received_cards_list[i]!='Ace':
      points+=received_cards_list[i]
    else:
      #If one of the cards picked is an ace, its value will be assumed to be 11 if
      #the total points is between 19 and 21 inclusively, and it will be 1 otherwise.
      x=11+points
      if x>21 or x<19:
        points+=1
      else:
        points+=11
  return points

def assign_further_points(card,points): 
#The assign_further_points adds the points of each additional card picked by
#either the player or the dealer to their respective total amount of points.
  if card!='Ace':
    points+=card
  else:
    x=points+11
    if x>21 or x<19:
      points+=1
    else:
      points+=11
  return points

def check_bust(points):
#The check_bust function verifies if the player or the dealer's points are
#higher than 21, which would automatically end the game.
  if points>21:
    return True
  else:
    return False

def hit(strategy,points):
#The hit function determines whether the player should hit or stand
#depending on the strategy he is currently using.
  if points>strategy:
    return False
  else:
    return True

def hit_dealer(dealer_points):
#The hit function determines whether the dealer hits or stands
#depending on whether his points are greater than or equal to 17.
  if dealer_points>=17:
    return False
  else:
    return True

def play_blackjack(strategy,deck):
#The play_blackjack function uses the previously mentioned functions to simulate
#a game of blackjack.
  received_cards_list=[]
  points=0
  dealer_points=0

#This block of code serves to pick the player's first two cards and assign
#their values to his total amount of points. The len(deck)==0 condition is present
#before each picking of a card so that it reshuffles the deck if the deck is empty.
  if len(deck)==0:
    deck=shuffle_decks()
  picked_card=receive_card(deck)
  received_cards_list.append(picked_card)
  if len(deck)==0:
    deck=shuffle_decks()
  picked_card_2=receive_card(deck)
  received_cards_list.append(picked_card_2)
  points=assign_initial_points(received_cards_list,points)
 
 
#As long as the player has not busted yet, he can choose to hit or stand
#depending on the strategy he is using.
  while check_bust(points)==False:
    if hit(strategy,points)==False:
      break
    else:
      if len(deck)==0:
        deck=shuffle_decks()
      picked_card=receive_card(deck)
      points=assign_further_points(picked_card,points)

#Once the player has ended by either busting or standing, we can proceed with
#the dealer's cards. 
  if len(deck)==0:
    deck=shuffle_decks()
  dealer_picked_card=receive_card(deck)
  dealer_points=assign_further_points(dealer_picked_card,dealer_points)

#The dealer will keep on hitting until he either lands between 17 and 21
#or busts (goes directly above 21) 
  while check_bust(dealer_points)==False:
    if hit_dealer(dealer_points)==False:
      break
    else:
      if len(deck)==0:
        deck=shuffle_decks()
      dealer_picked_card=receive_card(deck)
      dealer_points=assign_further_points(dealer_picked_card,dealer_points)

#If the player has more points than the dealer and did not go over 21, or 
#if the player has less than 21 points and the dealer busted, we will say
#that the player won. In all other cases, we will assume that the player has 
#lost (if the player ties, we consider it a loss).
  if (points>dealer_points and points<=21) or (points<=21 and dealer_points>21):
    return True
  else:
    return False
#The function play_blackjack will return True if the player wins, and False if he loses.

# %% [markdown]
# ## PHASE 2

# %%
list_of_games=[]
list_of_results=[]
pandas_list=[]
list_of_strategies=[]
total=0
deck=shuffle_decks()
random.seed(10) #This function is useful in order to make each simulation give the same random results, because it will make each simualation start at the same place.
#For each strategy, the game is played 1000 times. The amount of wins
#are recorded in the list_of_results and then added to the pandas_list.
#This experiment is then repeated 100 times, so that we can get an average 
#of wins for each strategy used. The first game starts with a shuffled deck,
#and the deck will slowly go down in each game until it is emptied, where it is
#shuffled again in the play_blackjack function to keep playing the game.


#This code takes approximatively 4 min seconds to run
for j in range(0,100):
  for strategy in range(9,20):
    list_of_strategies.append(strategy)
    for i in range(0,1000):
      if play_blackjack(strategy,deck)==True:
        list_of_results.append(1)
        list_of_games.append(1)
      else:
        list_of_results.append(0)
        list_of_games.append(1)
      total+=list_of_results[i]
    pandas_list.append(total)
    total=0
    list_of_results=[]
print(pandas_list)
# Out:
# [396, 410, 395, 422, 445, 429, 417, 403, 374, 377, 297, 394, 426, 408, 436, 407, 410, 422, 416, 369, 326, 282, 411, 412, 408, 446, 458, 437, 417, 408, 369, 371, 276, 409, 420, 436, 414, 425, 424, 408, 417, 383, 359, 272, 374, 376, 419, 431, 428, 413, 416, 420, 386, 336, 292, 402, 388, 432, 437, 419, 424, 405, 409, 418, 345, 289, 390, 392, 421, 419, 417, 424, 390, 416, 400, 361, 293, 414, 392, 445, 416, 408, 409, 424, 413, 393, 341, 267, 395, 415, 406, 440, 415, 415, 432, 415, 366, 363, 285, 398, 380, 444, 427, 408, 451, 432, 425, 403, 322, 278, 401, 433, 433, 410, 437, 409, 387, 391, 411, 362, 287, 365, 411, 460, 427, 445, 422, 430, 414, 375, 369, 293, 417, 401, 412, 430, 388, 443, 432, 425, 429, 368, 263, 403, 396, 438, 449, 430, 417, 433, 397, 389, 356, 251, 403, 402, 410, 406, 432, 421, 419, 427, 370, 363, 281, 385, 399, 424, 431, 440, 424, 386, 401, 406, 387, 296, 376, 379, 447, 413, 435, 438, 418, 400, 380, 347, 271, 401, 415, 412, 392, 418, 434, 423, 391, 390, 325, 307, 380, 38
# ...

# %%
print("The average probability of winning a game of Blackjack, no matter the hand is:",((sum(pandas_list)/len(pandas_list))/10),"%")
# Out:
# The average probability of winning a game of Blackjack, no matter the hand is: 39.405818181818184 %

# %% [markdown]
# ## PHASE 3

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt



#We create a dataframe containing the average number of wins out of 1000 games
#according to the strategy used.
data={'Strategies':list_of_strategies,
        'Games won':pandas_list}
df=pd.DataFrame(data=data);
results=df.groupby("Strategies")

# %%
#This shows the Standard error for each strategy
error=results.sem()
print (error)
# Out:
#             Games won
# Strategies
# 9            1.466615
# 10           1.567515
# 11           1.472123
# 12           1.526136
# 13           1.705858
# 14           1.530317
# 15           1.681118
# 16           1.513568
# 17           1.502226
# 18           1.479725
# 19           1.394605

# %%
#This code lets us plot the graph of the dataframe previously mentioned.
fig, ax = plt.subplots(figsize=(18,10))
ax=sns.barplot(
    data=df,
    x='Strategies',
    y='Games won',
    ci=95, #This shows a confidence interval of 95% on each bar of the barplot
    capsize=0.3

)
ax.set_xlabel("Last point total up to which the player hits",fontsize=24);
ax.set_ylabel("Number of Games Won out of 1000",fontsize=24);
ax.set_title('Probability of Winning a Blackjack Game Based on the Strategy Used',fontsize=30);
ax.annotate(('Maximum number of games won: 428'), xy= (3,428),
            xytext= (3.50,440), arrowprops= dict(facecolor= 'red', shrink=2),fontsize=15);

# %% [markdown]
# ##Results
#
# When running our simualtion, we used the official BlackJack rules as a model. From the graph, it can be seen that the best strategy to increase a player's probability of winning is when the players hits until he reaches a hand of 12. Our simualtion concluded that when the player decide that the last card up to which he hits is 12, he won 428 games out of 1000. Therefore he had a 42.80% probability of winning a game of Blackjack by using this strategy. The number of games won out of 1000 increases as the hand at which the player decide to hit up to increases, until it reaches 12.Then, the number of games won out of 1000 (and therefore the probability of winning a game) decreases as the  the hand at which the player decide to hit up to increases.
# ##
# Thus, the hand at which the player decides to hit up to affects his probability of winning in the following way: from the hands of 9 to 12, as his hand value increases, his probability also increases. However, from the hands having value from 13 to 19, his probability decreases as the hand value until which he decides to hit increases. It is also important to note that the range of error makes it so that the number of games won out of 1000 for the hands of 11, 12 and 13 are really close to each other, almost identical. The reason behind that and the analysis of the results will be further discussed in our discusion of results.

# %% [markdown]
# ## Validation of Results
#
# When comparing our results with data present in articles specialized in Blackjack probabilities, we can observe that the results of our model are validated. As a matter of fact, our model shows that the average probability of winning a Blackjack game, no matter the hand, is 39.41%, with our maximum probability of winning being 42.80% (for the hand of 12). This means that our model predicts that the dealer (the house) has more than 50% to win the game. Therefore, our model predicts that the house has an edge.
# ##
# This is validated by two articles focused on calculating the probabilities of winning a game in Blackjack. These articles are the articles of Matt Blake (section's footnote 1) and of Jeremiah Booker (section's footnote 2). As a matter of fact, both these articles determined that “in any round of a game of blackjack, the probability of an overall win is about 42.22%. The chances of a loss and a tie are 49.10% and 8.48% respectively” (Blake). Since we considered a tie to be considered as a loss in our model, we can add the probabilities to get that the player has 42.22% of winning a game of Blackjack and 57.78% of not winning the game against the dealer.
# ##
# On top of that, the article of John Grochowski (section's footnote 3) also explains that the house has an edge. Now that we validated that our model correctly predicts that the house has an edge, let us analyze our results in more depth. Our maximum probability of winning a Blackjack game is 42.80% and the average probability our model determined was 39.41%. Even tough this value is really close to other valid models and calculated probabilities (which determined a probability of 42.22%), there must be a valid reason to explain the small difference between both of the values.
# ##
# One possible reason could be due to the variety of strategies our model lets the player use. Indeed, the model only gave the player the options to hit or stand, and only at certain hands, no matter the situation. For games where the player decided for himself, he would have had a larger array of strategies and he would not have been limited by an imposed number until which he has to hit. The article from *BetAndBeat* ( section's footnote 4) confirms this: “a solid blackjack basic strategy does help in increasing the winning odds of the blackjack player”. For instance, one of the strategies in our model is to hit until the player reaches 19 points, but very few players would actually hit at this moment because the chances of busting are significantly large.
# ##
# Therefore, the lack of variety in strategies is one factor that explains why our average probability of winning a game no matter the hand is a little lower than the officially calculated ones. However, since there is a valid justification and the difference is relatively small, our model remains valid when compared to official probabilities of winning a game of Blackjack.
#
# Section's Footnotes:
#
# 1. Blake, Matt. “Blackjack odds & house edge explained.” *OnlineGambling*. 1 December 2020. https://www.onlinegambling.com/blackjack/odds. Accessed 16 May 2022.
#
# 2. Booker, Jeremiah. “Blackjack Probability of Winning – Odds for Each Hand.” *Best US Casinos*. 9 February 2022. https://www.bestuscasinos.org/blog/blackjack-probability-of-winning-odds-for-each-hand. Accessed 16 May 2022.
#
# 3. Grochowski, John. “Why Does the House Have an Edge in Blackjack.” *TunicaMS*. 19 May 2017. https://tunicatravel.com/blog/2017/05/why-does-the-house-have-an-edge-in-blackjack/. Accessed 16 May 2022.
#
# 4. “Is Blackjack a Fair Game.” *BetAndBeat*. 1 December 2020. https://betandbeat.com/blackjack/blog/is-blackjack-fair. Accessed 16 May 2022.

# %% [markdown]
# ##Discussion of Results
#
# Our results show that as the point total until which the player decides to hit increases from 9 to 12, the probability of the player winning the game of Blackjack also increases. Additionally, as the point total until which the player decides to hit increases from 13 to 19, the probability of the player winning the game of Blackjack decreases. Hence, the hypothesis we made in the beginning was wrong. This can be explained by the way Blackjack is played. As a matter of fact, as the point total of the hand until which the players hit increases, it increases the risk of the player busting. In fact, even though it is intuitive to think that if the player hits until a higher card, he has a higher chance of beating the dealer, there is one aspect that was not considered. For instance, if the player decides to follow the strategy that says that he will hit until he reaches a card of 17, this means that there will be more occurrences of him hitting when he has a high value hand, such as 16. Hitting on higher value hands increases the chances of the point total with the additional card exceeding 21, therefore causing the player to bust and lose the game.
# ##
# In other words, our model shows that there are more risks for the player to bust if he hits until he reaches hands having values greater than 12 than if he hits until he reaches hand values lower than 13. This is because for hand values totalling up 13 points and more, there are more possibility of cards that will cause to exceed 21 than there are possibilities of cards that will cause hands of 12 points and less from exceeding 21. For example, if the hand has a value of 12 and the player decides to hit, only the 10s and the faces can make him exceed 21 (because he will choose the ace to be worth 1 instead of 11). However, if the hand has a value of 15 and the player decides to hit, the 10s, the faces, the 9s, the 8s and the 7s can make him exceed 21.
# ##
# It is also important to note that the action of reshuffling the deck only when it empties not only follows the official way of playing Blackjack in the casinos, but it also does not significantly affect the average probability of getting a card in particular, since the simualtion is run 1000 times.
#
# To continue, our model shows that the number of games won out of 1000 for the strategies where the last hand at which the player hits are 11, 12 or 13 are very close to each other. This can be explained by the fact that our model has uncertainties. One of the reasons we have uncertainties is because we gave the player the possibility to use only one strategy, which caused him to not always pick the optimal choice for the value of the Ace card. Indeed, in our model, the Ace card will be worth 11 points only if the total points that will result from the addition of it is between 21 and 19. Even tough this is a good strategy and it serves well the purposes of our model, it can result in certain uncertainties since some players may decide to play the Ace differently, which will impact at what point total they accomplish one of the strategies.
# ##
# Another reason of this uncertainty is caused by the Blackjack game itself. In fact, this is a gambling game, and chance is a great part of the game. Consequently, even when run 100 times where for each time it simulated 1000 games per strategy, our model still has uncertainties.  The reason our model runs so many games, so many times, is because we wanted to minimize as much as possible the effects of chance on our probabilities.
#
# In our model, we designed our graph to show the confidence intervals for each strategies. Specifically, the model draws the interval estimates on top of each bar such that 95% of the means of each group are contained within these estimates.
# ##
# Furthermore, we created in our model a dataframe which contains the standard errors for each strategy. By analyzing it, we can conclude that the hands of 11, 12 and 13 are indeed very close to each other when uncertainties are considered. For instance, the results our model gave us when last run was that the occurrence where the player decided to hit until he reached a hand of 11 won him 424 ± 1.47 games, the hand of 12 won 428± 1.53 games, and the hand of 13 won 426± 1.71 games (all out of 1000). Based on these uncertainties, the three hands yield very similar number of games won, and there is a possibility that the hand of 13 yields more wins (if the hand of 12 actual yield is 428-1.53 games and that of the hand of 13, 426+1.71 games). This is once again due to the randomness of the game.
# ##
# In addition to giving a detailed answer to our problem, this can also be useful to solve another problem. Actually, if we wanted to expand this project to include the betting aspect of Blackjack, the player will know which strategies are the most interesting to double down one. To illustrate, the player who wants to hit one last time by doubling his bet will know that the most efficient strategies are if his last hit is when his hand’s point total is 11, 12 or 13, with the best strategy being to hit until his hand is 12 points.
# ##
# To conclude this project, let us once again answer our problem: the probability of winning a game of Blackjack increases when the point total until which the player decides to hit increases from 9 to 12, and decreases when the point total until which the player decides to hit increases from 13 to 19.

# %% [markdown]
# ##References
#
#
# Blake, Matt. “Blackjack odds & house edge explained.” *OnlineGambling*. 1 December 2020. https://www.onlinegambling.com/blackjack/odds. Accessed 16 May 2022.
#
#
# Booker, Jeremiah. “Blackjack Probability of Winning – Odds for Each Hand.” *Best US Casinos*. 9 February 2022. https://www.bestuscasinos.org/blog/blackjack-probability-of-winning-odds-for-each-hand. Accessed 16 May 2022.
#
#
# Garvie, Duncan. “Blackjack.” *Pagat*. 3 January 2021. www.pagat.com/banking/blackjack.html. Accessed 14 May 2022.
#
#
# Grochowski, John. “Why Does the House Have an Edge in Blackjack.” *TunicaMS*. 19 May 2017. https://tunicatravel.com/blog/2017/05/why-does-the-house-have-an-edge-in-blackjack/. Accessed 16 May 2022.
#
#
# “Is Blackjack a Fair Game.” *BetAndBeat*. 1 December 2020. https://betandbeat.com/blackjack/blog/is-blackjack-fair. Accessed 16 May 2022.
#
#
# “Play Online Blackjack.” *PokerStars Casino*. 2022. https://cad.pokerstarscasino.com/games/blackjack/. Accessed 14 May 2022.
